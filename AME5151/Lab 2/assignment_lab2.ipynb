# %%
import numpy as np

# %%
x_inputs = np.random.rand(10)
x_inputs
# Out:
# array([0.53874621, 0.21836642, 0.45269748, 0.50610246, 0.53224213,
#        0.18523151, 0.35418837, 0.4692157 , 0.7394428 , 0.8337469 ])

# %%
weights = np.random.rand(10)
weights
# Out:
# array([0.79655354, 0.63441507, 0.39276162, 0.75214515, 0.03104048,
#        0.60590739, 0.69009942, 0.5989131 , 0.05686027, 0.14227413])

# %%
dot_product = np.dot(x_inputs, weights)
dot_product
# Out:
# np.float64(1.8201082646941382)

# %%
bias = np.random.randint(0, 10)
output = dot_product + bias
output
# Out:
# np.float64(4.820108264694138)
